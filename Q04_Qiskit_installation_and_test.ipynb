# %% [markdown]
# <font style="font-size:28px;" align="left"><b> Qiskit installation and test </b></font>

# %% [markdown]
# - [Check your system](#check)
# - [Install qiskit](#install)
# - [Tips](#tips)
# - [Execute an example quantum program](#test)

# %% [markdown]
# <hr id="check">
#
# ### Check your system
#
# Check your system, if Qiskit has already been installed:

# %%
import qiskit
versions = qiskit.__version__
print("The version of Qiskit is",versions)
# Out:
# The version of Qiskit is 1.4.2

# %%
# !pip install matplotlib
# !pip install pylatexenc
# Out:
# Requirement already satisfied: matplotlib in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting pylatexenc
#   Using cached pylatexenc-2.10.tar.gz (162 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (pyproject.toml) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136897 sha256=4b362b320043b3681fdbb4609a52ef6df451ee4757e786561eef8f9f407ab874
#   Stored in directory: /Users/yassinefer/Library/Caches/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# **You should be able to see the version number of any library that is already installed in your system.**

# %% [markdown]
# <hr id="install">
#
# ### Install qiskit
#
# (If you are an experienced user, visit this link: https://docs.quantum-computing.ibm.com/start/install)
#
# You can install Qiskit by executing the following cell:

# %%
# !pip install "qiskit[visualization]">=1.0 --user
# Out:
# zsh:1: 1.0 not found

# %%
# !pip install qiskit-aer --user
# Out:
# Requirement already satisfied: qiskit-aer in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: qiskit>=1.1.0 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit-aer) (1.4.2)
# Requirement already satisfied: numpy>=1.16.3 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit-aer) (2.2.4)
# Requirement already satisfied: scipy>=1.0 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit-aer) (1.15.2)
# Requirement already satisfied: psutil>=5 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit-aer) (7.0.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.16.0)
# Requirement already satisfied: sympy>=1.3 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.4.1)
# Requirement already satisfied: typing-extensions in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.13.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (6.1.1)
# Requirement already satisfied: setuptools in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (65.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/yassinefer/.pyenv/versions/3.10.16/lib/python3.10/site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit-aer) (1.3.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# __*Restart the kernel*__ (check "Kernel" menu) to apply the changes to the current notebook.

# %% [markdown]
# <hr id="tips">
#
# ### Tips
#
# _Any terminal/shell command can be executed in the notebook cells by putting an exclamation mark (!) at the beginning of the command._
#
# _$\rightarrow$ To update Qiskit to the latest version, execute the following command in a code cell_
#
#     !pip install -U qiskit --user
#
# _$\rightarrow$ To uninstall Qiskit, execute the following command in a code cell_
#
#     !pip uninstall qiskit

# %%
#!pip install -U qiskit --user
#!pip uninstall qiskit

# %% [markdown]
# <hr id="test">
#
# ### Execute an example quantum program

# %% [markdown]
# 1) Create a quantum circuit

# %%
# import the objects from qiskit
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit_aer import AerSimulator
from random import randrange

# create a quantum circuit and its register objects
qreg = QuantumRegister(2) # quantum register with two quantum bits
creg = ClassicalRegister(2) # classical register with two classical bit
circuit = QuantumCircuit(qreg,creg) # quantum circuit composed by a quantum register and a classical register

# apply a Hadamard gate to the first qubit
circuit.h(qreg[0])

# set the second qubit to state |1>
circuit.x(qreg[1])

# apply CNOT(first_qubit,second_qubit)
circuit.cx(qreg[0],qreg[1])

# measure the both qubits
circuit.measure(qreg,creg)

print("The execution of the cell was completed, and the circuit was created :)")
# Out:
# The execution of the cell was completed, and the circuit was created :)

# %% [markdown]
# 2) Draw the circuit
#
# _Run the cell once more if the figure is not shown_

# %%
# draw circuit 
circuit.draw(output='mpl')

# the output will be a "matplotlib.Figure" object
